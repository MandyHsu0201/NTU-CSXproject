# %%
### 使用Post,pandas

# %%
from selenium import webdriver
driver=webdriver.Chrome(r'C:\Users\Ellipsiz\Desktop\chromedriver.exe')
driver.get('https://shopee.tw/')

# %%
import requests
import json
import pandas as pd

# %%
#網頁案右的檢查後，進入network(接著重新整裡網頁)\doc，發現沒找到跟網頁有關的訊息ex:價錢
#改看XHR，可用Preview(會將response的資訊整理得比較好觀察)，從中發現在items有相關訊息，表示找對了
#貼上header上的網址，並使用get或post來讀取(上面會寫是get或post)
#發現是post，則須貼入更多的資訊
#從header\Request Paylod 發現很像json的格式，需用josn的格式，接著看到viewsource將其按開，則出現的東西就是要貼入我們post的內容
#所以需要引用json，並將他load出來
#暫時將下面一行mark
#requests.post('from selenium import webdriver

jd=json.loads('{"item_shop_ids":[{"itemid":39747180,"campaignid":68170,"shopid":5977996,"adsid":68170,"ads_keyword":"手機","logisticid":[39304,30005,30001],"deduction_info":"a3V2NW02MGxxcGxqeWhidJePRCcB3xpEuuo1pMtUerZLALmc/4TYC5FJSZZ9KHFWb0XXYtUZX7JNo77eBHm/Lw=="},{"itemid":707991989,"campaignid":322811,"shopid":9222401,"adsid":322811,"ads_keyword":"手機","logisticid":[30005,30006,30007],"deduction_info":"a3V2NW02MGxxcGxqeWhidL8FCGUihPMQOWKs73W7z/6Ij9ZGlfcJRM5JLKXvmRmc+WhV6Q0AD0SuPpZnbkg2lQ=="},{"itemid":65306904,"campaignid":68171,"shopid":5977996,"adsid":68171,"ads_keyword":"手機","logisticid":[30005,39304,30001],"deduction_info":"a3V2NW02MGxxcGxqeWhidBdsswg7hGFjAgDCTCS6Q1rh6oQMBKtn4dsnzPQVDI5JHawjFU5bawvVMf95NYuaLg=="},{"itemid":694861124,"campaignid":305232,"shopid":43997244,"adsid":305232,"ads_keyword":"手機","logisticid":[30006,30005,39303],"deduction_info":"a3V2NW02MGxxcGxqeWhidFH2TULjwKD0b2SOqEACWc2zbiTW1sHGZOWIEuNgJjuRaMu4wlK/otmSgey9CNqq1Q=="},{"itemid":846184303,"campaignid":384973,"shopid":4827179,"adsid":384872,"ads_keyword":"手機","logisticid":[30006,30005,39303],"deduction_info":"a3V2NW02MGxxcGxqeWhidEIit8YhHF8I/VCPzyzvqiknUHMzGYs/l5ZDisscNAqVBvLCGpRLQKf1GiVy1LdB/w=="},{"itemid":802316023,"shopid":15171156,"logisticid":[30001,30005]},{"itemid":888957119,"shopid":1580315,"logisticid":[30006,30007,39304,30005]},{"itemid":815532393,"shopid":20990061,"logisticid":[30005,30006,39304]},{"itemid":794487371,"shopid":17371416,"logisticid":[30005]},{"itemid":132018096,"shopid":540615,"logisticid":[30007,39304,30005,30001,30006]},{"itemid":621230590,"shopid":22204594,"logisticid":[30006,30007,30005]},{"itemid":760203527,"shopid":16295631,"logisticid":[30006,30005]},{"itemid":622883247,"shopid":12448,"logisticid":[30006,30007,39304,30005,39303]},{"itemid":937617153,"shopid":4975228,"logisticid":[30005,30006,30007]},{"itemid":888979052,"shopid":1580315,"logisticid":[30007,39304,30005,30006]},{"itemid":780979340,"shopid":176939,"logisticid":[30001,30006,39304,30005]},{"itemid":690930182,"shopid":10936709,"logisticid":[30007,30005,30006]},{"itemid":668288646,"shopid":3274118,"logisticid":[30006,30007,39304,30005]},{"itemid":937723143,"shopid":6796474,"logisticid":[30006,39304,30005]},{"itemid":763505972,"shopid":46219085,"logisticid":[30005]},{"itemid":755402240,"shopid":7880605,"logisticid":[39304,39303,30006,30007]},{"itemid":599546687,"shopid":1817932,"logisticid":[39304,30005,39303,30006]},{"itemid":962591322,"shopid":53054911,"logisticid":[39304]},{"itemid":930462502,"shopid":12448,"logisticid":[30006,30007,39304,30005,39303]},{"itemid":902825622,"shopid":2523168,"logisticid":[30006,30007,30005,30001,39304,39303]},{"itemid":873958374,"shopid":6796474,"logisticid":[30006,39304,30005]},{"itemid":836854285,"shopid":3274118,"logisticid":[30005,30006,30007,39304]},{"itemid":823563132,"shopid":14669577,"logisticid":[30005,30006]},{"itemid":760191520,"shopid":16295631,"logisticid":[30006,30005]},{"itemid":708305095,"shopid":14084056,"logisticid":[30006,30007,39304,30005]},{"itemid":952966922,"shopid":3564025,"logisticid":[30005,30001]},{"itemid":941719659,"shopid":13915867,"logisticid":[30006,30005]},{"itemid":901985077,"shopid":43839500,"logisticid":[30005,30001,39304,39303,30006,30007]},{"itemid":899714587,"shopid":20990061,"logisticid":[30006,39304,30005]},{"itemid":896158380,"shopid":26592040,"logisticid":[30006,39304,39303]},{"itemid":887634543,"shopid":1886239,"logisticid":[30006,30005]},{"itemid":866009568,"shopid":9466363,"logisticid":[30005,30001,30006,30007,39304]},{"itemid":862150616,"shopid":2646347,"logisticid":[30006,39304,30005,30001]},{"itemid":859146778,"shopid":3123569,"logisticid":[30005,30006,30007,39303,39304]},{"itemid":827088886,"shopid":51701199,"logisticid":[30005,30006,39304,30001]},{"itemid":806226534,"shopid":6479608,"logisticid":[30007,39303,30001,30005,30006]},{"itemid":707982838,"shopid":14084056,"logisticid":[30007,39304,30005,30006]},{"itemid":588296072,"shopid":1419401,"logisticid":[30006,30007,30005,39303,30001]},{"itemid":88487723,"shopid":2651322,"logisticid":[39303,30006,30007,30005]},{"itemid":983997431,"shopid":8793687,"logisticid":[30007,30001,30005,30006]},{"itemid":658669937,"campaignid":286735,"shopid":4031525,"adsid":286735,"ads_keyword":"手機","logisticid":[30006,30007,39304,30005],"deduction_info":"a3V2NW02MGxxcGxqeWhidA7cSTI0fwHPhF7YXu6omLUK39W8Ep6BpNMqs7ClXp0Xnl1qZVFbNKjQ63ijGMCbEw=="},{"itemid":790338604,"campaignid":381212,"shopid":49198003,"adsid":381111,"ads_keyword":"手機","logisticid":[30006,39304,30005,39303],"deduction_info":"a3V2NW02MGxxcGxqeWhidO9hRFiYW5af7sSLyltS3dmWtjpcxUb1R4x3EnblM23U11TYcuuKDz4zXYZ0dzxh2A=="},{"itemid":891219167,"campaignid":390928,"shopid":4067127,"adsid":390827,"ads_keyword":"手機","logisticid":[30005,30006,30007,39303],"deduction_info":"a3V2NW02MGxxcGxqeWhidL8FCGUihPMQOWKs73W7z/7ZFLbN3OLVXR80qxBeMROly/F81zxltzTUFmyuMyLb6g=="},{"itemid":48211966,"campaignid":152362,"shopid":1494597,"adsid":152362,"ads_keyword":"手機","logisticid":[30006,30007,39304,30005],"deduction_info":"a3V2NW02MGxxcGxqeWhidLNTTCtELBWRq+laju0cDQJ+BUmCdS/HSgphaVEOF4AfOyYJQuqTTQ3p8qZF7Ws/Ew=="},{"itemid":242609117,"campaignid":76293,"shopid":2841469,"adsid":76293,"ads_keyword":"手機","logisticid":[39304,39303,30006,30007,30005,30001],"deduction_info":"a3V2NW02MGxxcGxqeWhidOKRLjteYFM551Dx7tYkcL1UgJe/FpihqnswPqENEnQMZnKdn6VvS+XHQHvTVTIDHQ=="}]}')
#jd

#再將jd，mark，並重新編寫request.post
#res=requests.post('https://shopee.tw/api/v1/items/',json=jd)
#res#res

#結果得到response[403]，表示存取失敗
#所以應該加入更多headers的資訊，一步一步慢慢嘗試
headers={
  'cookie':'cto_lwid=834c8f3c-53da-4d08-ac57-25fd42046a61; _ga=GA1.2.951162321.1516028199; SPC_IA=-1; SPC_EC=-; SPC_U=-; SPC_F=XDvYZA8eWj75kiS7sWmRJuvx4yTWfCOD; REC_T_ID=4b792038-fa04-11e7-9484-d09466041b51; SPC_T_ID="NLAHfrWXIORWvzJLQ8C0UdgVPxUAQxb4QFa4F7zPFQVZ6FJxr5Dp0tsyxXQEphRa0h99f+y5qTs7AerpbQuKGbfcTvdMn5FCfA4M7PxVkNs="; SPC_T_IV="d5xJIZMUEV3kt296KjNc+g=="; __BWfp=c1516028254731x0e8ac793d; _gac_UA-61915057-6=1.1518008729.CjwKCAiA5OrTBRBlEiwAXXhT6O_d8L6_7RTTvA4WR2LB0PM1b41KCwOdUCejvfGcPngV74xaoeqbiRoCmpMQAvD_BwE; _gid=GA1.2.1563060899.1521040945; _gat=1; csrftoken=Bg3ML75wPo8I3WnL33f91gcrIrfjbbeN; SPC_SI=c7ujsthkozk9jdrj3a2omir8l9bnovtj; SPC_SC_TK=; UYOMAPJWEMDGJ=; SPC_SC_UD=',
    'referer':'https://shopee.tw/search/?keyword=%E6%89%8B%E6%A9%9F',
    'x-csrftoken':'Bg3ML75wPo8I3WnL33f91gcrIrfjbbeN',
   'user-agent':'Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/64.0.3282.186 Safari/537.36'
}
#重新在res內加入headers
res=requests.post('https://shopee.tw/api/v1/items/',json=jd,headers=headers)
res 
#還是得到403，再回到headers內，繼續加入x-csrftoken(記得將它表示成字典格式，也就是用單引號將冒號前後的字分開)，
#還是403則繼續加，直到加入referer時結果出現200，表示成功讀取
# Out:
# <Response [200]>

# %%
#將res用文字檔列出來
#res.text
#也可改用json格式去讀取
res.json()
#回頭看我們的headers的內容，user-agent是表示讓我們像人一樣去瀏覽這個網頁
#referer是從哪邊導過來的
#若把cookie，x-csrftoken mark起來會發現無法讀取(result=403)
#回到網頁的檢查\network\XHR\cookies，可發現裡面有csrftoken及其他組成的cookie，需要透過API去得到裡面的資訊(沒效益)
#最好有一個瀏覽器可以直接開起來，複製這些cookie，當成我們的headers
#可借用selenium來達到上面的目的(取得cookie)
#回到一開始的地方加入 from selenium import webdriver
# driver=webdriver.Chrome()
# Out:
# [{'attributes': [],
#   'brand': '無',
#   'bundle_deal_info': None,
#   'can_use_bundle_deal': False,
#   'can_use_wholesale': False,
#   'catid': 10076,
#   'cb_option': 0,
#   'cmt_count': 171,
#   'coin_earn_items': None,
#   'coin_spend_cash_unit': None,
#   'condition': 1,
#   'currency': 'TWD',
#   'description': None,
#   'discount': None,
#   'estimated_days': 7,
#   'flash_sale': None,
#   'free_return_day': 15,
#   'has_lowest_price_guarantee': False,
#   'hashtag_list': [],
#   'image': '2becb34bd4a8f573b981bf46c5485712',
#   'image_list': ['2becb34bd4a8f573b981bf46c5485712',
#    'f5b6fc63a41243535a8355b6e50c1fcf',
#    '88f7ec3b2990eb6beaf07aa4c797af89',
#    '53c7952b249787f1ac6685934b730f02',
#    '782e42a7be0281e85cb858b422a4f869',
#    '16ffa2852fee58db53b3a19cfd6e1801',
#    '1258ff75fef1f9b335024e40d3d37693'],
#   'installment_plans': None,
#   'is_adult': None,
#   'is_category_failed': False,
#   'is_cc_installment_payment_eligible': False,
#   'is_installment_payment_eligible': False,
#   'is_non_cc_installment_payment_eligible': False,
#   'is_official_shop': False,
#   'is_pre_order': True,
#   'is_shopee_verified': False,
#   'item_status': 'normal',
#   'itemid': 39747180,
#   'liked': False,
#   'liked_count': 310,
#   'models': [{'ctime': 1467733512,
#     'currency': 'TWD',
#     'extinfo': {'seller_promotion_limit': 0,
#      'seller_promotion_refresh_time': 0},
#     'itemid': 39747180,
#     'modelid': 22879475,
#     'mtime': 1474603152,
#     'name': '鎖後照鏡(螺絲孔)',
#     'price': 39000000,
#     'price_before_discount': 0,
#     'promotionid': 0,
#     'rebate_price': 0,
#     'sku': '',
#     'sold': 235,
#     'status': 1,
#     'stock': 760},
#    {'ctime': 1467733512,
#     'currency': 'TWD',
#     'extinfo': {'seller_promotion_limit': 0,
#      'seller_promotion_refresh_time': 0},
#     'itemid': 39747180,
#     'modelid': 22879476,
#     'mtime': 1474603152,
#     'name': '鎖車把(橫桿)',
#     'price': 39000000,
#     'price_before_discount': 0,
#     'promotionid': 0,
#     'rebate_price': 0,
#     'sku': '',
#     'sold': 28,
#     'status': 1,
#     'stock': 971},
#    {'ctime': 1494833047,
#     'currency': 'TWD',
#     'itemid': 39747180,
#     'modelid': 170615123,
#     'mtime': 1494833047,
#     'name': '沒充電功能',
#     'price': 37000000,
#     'price_before_discount': 0,
#     'promotionid': 0,
#     'rebate_price': 0,
#     'sku': '',
#     'sold': 17,
#     'status': 1,
#     'stock': 968}],
#   'name': 'Moto7 手機架 USB車充 機車手機支架 勁戰/BWS/RSZ/CUXI/雷霆王/G6/JET/VJR/MANY',
#   'offer_count': 0,
#   'price': 37000000,
#   'price_before_discount': 0,
#   'price_max': 39000000,
#   'price_max_before_discount': -1,
#   'price_min': 37000000,
#   'price_min_before_discount': -1,
#   'rating_count': [114, 2, 0, 4, 11, 97],
#   'rating_star': 4.7631578947368425,
#   'raw_discount': None,
#   'rcount_with_context': 55,
#   'rcount_with_image': 1,
#   'service_by_shopee_flag': 0,
#   'shopid': 5977996,
#   'show_discount': 0,
#   'show_free_shipping': False,
#   'sold': 17,
#   'stock': 2699,
#   'sub_catid': 10086,
#   'third_catid': 10133,
#   'videos': [],
#   'wholesale_tier_list': []},
#  {'attributes': [],
#   'brand': None,
#   'bundle_deal_info': None,
#   'can_use_bundle_deal': False,
#   'can_use_wholesale': False,
#   'catid': 70,
#   'cb_option': 0,
#   'cmt_count': 0,
#   'coin_earn_items': None,
#   'coin_spend_cash_unit': None,
#   'condition': 1,
#   'currency': 'TWD',
#   'description': None,
#   'discount': None,
#   'estimated_days': 7,
#   'flash_sale': None,
#   'free_return_day': 15,
#   'has_lowest_price_guarantee': False,
#   'hashtag_list': [],
#   'image': '5677ed834ea891f5a384354ffaf252d2',
#   'image_list': ['5677ed834ea891f5a384354ffaf252d2',
#    '49cc341d68f8e582c961c0e270aee230',
#    '06e311d88f8b08b0db83705290ada5f5'],
#   'installment_plans': None,
#   'is_adult': None,
#   'is_category_failed': False,
#   'is_cc_installment_payment_eligible': False,
#   'is_installment_payment_eligible': False,
#   'is_non_cc_installment_payment_eligible': False,
#   'is_official_shop': True,
#   'is_pre_order': True,
#   'is_shopee_verified': True,
#   'item_status': 'normal',
#   'itemid': 707991989,
#   'liked': False,
#   'liked_count': 5,
#   'models': [{'ctime': 1511436727,
#     'currency': 'TWD',
#     'extinfo': {'has_shopee_promo': False,
#      'seller_promotion_limit': 0,
#      'seller_promotion_refresh_time': 0,
#      'stockout_time': 0},
#     'itemid': 707991989,
#     'modelid': 557700344,
#     'mtime': 1520934691,
#     'name': 'ROLI515C1-#銀',
#     'price': 29900000,
#     'price_before_discount': 0,
#     'promotionid': 0,
#     'rebate_price': 0,
#     'sku': '201712AM260006167',
#     'sold': 0,
#     'status': 1,
#     'stock': 27},
#    {'ctime': 1511436727,
#     'currency': 'TWD',
#     'extinfo': {'has_shopee_promo': False,
#      'seller_promotion_limit': 0,
#      'seller_promotion_refresh_time': 0,
#      'stockout_time': 0},
#     'itemid': 707991989,
#     'modelid': 557700345,
#     'mtime': 1520524839,
#     'name': 'ROLI515C2- #金',
#     'price': 29900000,
#     'price_before_discount': 0,
#     'promotionid': 0,
#     'rebate_price': 0,
#     'sku': '201712AM260006168',
#     'sold': 0,
#     'status': 1,
#     'stock': 25},
#    {'ctime': 1511436727,
#     'currency': 'TWD',
#     'extinfo': {'has_shopee_promo': False,
#      'seller_promotion_limit': 0,
#      'seller_promotion_refresh_time': 0,
#      'stockout_time': 0},
#     'itemid': 707991989,
#     'modelid': 557700346,
#     'mtime': 1520934331,
#     'name': 'ROLI515C3-#玫瑰金',
#     'price': 29900000,
#     'price_before_discount': 0,
#     'promotionid': 0,
#     'rebate_price': 0,
#     'sku': '201712AM260006169',
#     'sold': 1,
#     'status': 1,
#     'stock': 21}],
#   'name': '360度網紅直播手機支架 一入【ROLI515C】◆86小舖◆',
#   'offer_count': 0,
#   'price': 29900000,
#   'price_before_discount': 0,
#   'price_max': 29900000,
#   'price_max_before_discount': -1,
#   'price_min': 29900000,
#   'price_min_before_discount': -1,
#   'rating_count': [0, 0, 0, 0, 0, 0],
#   'rating_star': 0,
#   'raw_discount': None,
#   'rcount_with_context': 0,
#   'rcount_with_image': 0,
#   'service_by_shopee_flag': 0,
#   'shopid': 9222401,
#   'show_discount': 0,
#   'show_free_shipping': True,
#   'sold': 0,
#   'stock': 73,
#   'sub_catid': 1579,
#   'third_catid': 7973,
#   'videos': [],
#   'wholesale_tier_list': []},
#  {'attributes': [],
#   'brand': '自有品牌',
#   'bundle_deal_info': None,
#   'can_use_bundle_deal': False,
#   'can_use_wholesale': True,
#   'catid': 10076,
#   'cb_option': 0,
#   'cmt_count': 82,
#   'coin_earn_items': None,
#   'coin_spend_cash_unit': None,
#   'condition': 1,
#   'currency': 'TWD',
#   'description': None,
#   'discount': None,
#   'estimated_days': 3,
#   'flash_sale': None,
#   'free_return_day': 15,
#   'has_lowest_price_guarantee': False,
#   'hashtag_list': [],
#   'image': '782e42a7be0281e85cb858b422a4f869',
#   'image_list': ['782e42a7be0281e85cb858b422a4f869',
#    '53c7952b249787f1ac6685934b730f02',
#    '88f7ec3b2990eb6beaf07aa4c797af89',
#    '16ffa2852fee58db53b3a19cfd6e1801',
#    'f5b6fc63a41243535a8355b6e50c1fcf',
#    '1258ff75fef1f9b335024e40d3d37693',
#    '858cb3487aa4f5e942bdd6eb0b583f03'],
#   'installment_plans': None,
#   'is_adult': None,
#   'is_category_failed': False,
#   'is_cc_installment_payment_eligible': False,
#   'is_installment_payment_eligible': False,
#   'is_non_cc_installment_payment_eligible': False,
#   'is_official_shop': False,
#   'is_pre_order': False,
#   'is_shopee_verified': False,
#   'item_status': 'normal',
#   'itemid': 65306904,
#   'liked': False,
#   'liked_count': 185,
#   'models': [{'ctime': 1473823240,
#     'currency': 'TWD',
#     'extinfo': {},
#     'itemid': 65306904,
#     'modelid': 51536393,
#     'mtime': 1473823240,
#     'name': '鎖後照鏡(螺絲孔)',
#     'price': 39000000,
#     'price_before_discount': 0,
#     'promotionid': 0,
#     'rebate_price': 0,
#     'sku': '',
#     'sold': 126,
#     'status': 1,
#     'stock': 871}],
#   'name': 'Moto7 手機架 USB車充 機車手機支架 勁戰/BWS/RSZ/CUXI/雷霆王/G6/JET/VJR/MANY/',
#   'offer_count': 0,
#   'price': 39000000,
#   'price_before_discount': 0,
#   'price_max': 39000000,
#   'price_max_before_discount': -1,
#   'price_min': 39000000,
#   'price_min_before_discount': -1,
#   'rating_count': [59, 0, 0, 4, 5, 50],
#   'rating_star': 4.779661016949152,
#   'raw_discount': None,
#   'rcount_with_context': 34,
#   'rcount_with_image': 1,
#   'service_by_shopee_flag': 0,
#   'shopid': 5977996,
#   'show_discount': 0,
#   'show_free_shipping': False,
#   'sold': 6,
#   'stock': 871,
#   'sub_catid': 10080,
#   'third_catid': 14530,
#   'videos': [],
#   'wholesale_tier_list': [{'min_count': 15, 'price': 32000000}]},
#  {'attributes': [],
#   'brand': 'M4 PLUS',
#   'bundle_deal_info': None,
#   'can_use_bundle_deal': False,
#   'can_use_wholesale': False,
#   'catid': 69,
#   'cb_option': 0,
#   'cmt_count': 572,
#   'coin_earn_items': None,
#   'coin_spend_cash_unit': None,
#   'condition': 1,
#   'currency': 'TWD',
#   'description': None,
#   'discount': None,
#   'estimated_days': 3,
#   'flash_sale': None,
#   'free_return_day': 15,
#   'has_lowest_price_guarantee': False,
#   'hashtag_list': [],
#   'image': '721c4637983a9d16431ba3a4c8e0874e',
#   'image_list': ['721c4637983a9d16431ba3a4c8e0874e',
#    '271b4f573a00b8343af9da6e1b71bbd9',
#    '25fc602fbe6d3634082bfc90986e0b6e',
#    'e182ebae2a11aae6750f07ac32e81ac4',
#    'f7bc4e6289ee3369a3cf05a158e9e324',
#    '6e23acb4853c95560f2318d848e0ca93',
#    'f85a6a79c632d6605f7148418aa3853e',
#    '71c3dced379b5c6a82428928511e93fa',
#    '7327d155a882991605e0f83b5b801db1'],
#   'installment_plans': None,
#   'is_adult': None,
#   'is_category_failed': False,
#   'is_cc_installment_payment_eligible': False,
#   'is_installment_payment_eligible': False,
#   'is_non_cc_installment_payment_eligible': False,
#   'is_official_shop': False,
#   'is_pre_order': False,
#   'is_shopee_verified': True,
#   'item_status': 'normal',
#   'itemid': 694861124,
#   'liked': False,
#   'liked_count': 281,
#   'models': [{'ctime': 1515220571,
#     'currency': 'TWD',
#     'extinfo': {'stockout_time': 0},
#     'itemid': 694861124,
#     'modelid': 695945577,
#     'mtime': 1520235186,
#     'name': 'M4PLUS(主機+電源天線+說明書)',
#     'price': 32000000,
#     'price_before_discount': 0,
#     'promotionid': 0,
#     'rebate_price': 0,
#     'sku': '',
#     'sold': 621,
#     'status': 1,
#     'stock': 59},
#    {'ctime': 1515220571,
#     'currency': 'TWD',
#     'extinfo': {'stockout_time': 0},
#     'itemid': 694861124,
#     'modelid': 695945578,
#     'mtime': 1516360773,
#     'name': 'HDMI公母延長線50CM 強烈建議加購',
#     'price': 6500000,
#     'price_before_discount': 0,
#     'promotionid': 0,
#     'rebate_price': 0,
#     'sku': '',
#     'sold': 263,
#     'status': 1,
#     'stock': 440}],
#   'name': '原廠正品 雷射防偽標簽  RK3036 AnyCast 手機電視棒 hdmi av  MHL M4 plus HDMI',
#   'offer_count': 0,
#   'price': 6500000,
#   'price_before_discount': 0,
#   'price_max': 32000000,
#   'price_max_before_discount': -1,
#   'price_min': 6500000,
#   'price_min_before_discount': -1,
#   'rating_count': [563, 2, 1, 5, 39, 516],
#   'rating_star': 4.893428063943162,
#   'raw_discount': None,
#   'rcount_with_context': 347,
#   'rcount_with_image': 2,
#   'service_by_shopee_flag': 0,
#   'shopid': 43997244,
#   'show_discount': 0,
#   'show_free_shipping': False,
#   'sold': 492,
#   'stock': 499,
#   'sub_catid': 298,
#   'third_catid': 5787,
#   'videos': [],
#   'wholesale_tier_list': []},
#  {'attributes': [],
#   'brand': 'M4PLUS',
#   'bundle_deal_info': None,
#   'can_use_bundle_deal': False,
#   'can_use_wholesale': False,
#   'catid': 70,
#   'cb_option': 0,
#   'cmt_count': 32,
#   'coin_earn_items': None,
#   'coin_spend_cash_unit': None,
#   'condition': 1,
#   'currency': 'TWD',
#   'description': None,
#   'discount': None,
#   'estimated_days': 3,
#   'flash_sale': None,
#   'free_return_day': 15,
#   'has_lowest_price_guarantee': False,
#   'hashtag_list': [],
#   'image': 'fff1ee30ec5980584d7ae658c437b01c',
#   'image_list': ['fff1ee30ec5980584d7ae658c437b01c',
#    '061c5d4a75dabd9f402ca4eb68af468c',
#    '8b237c90a0e161eba27bd1bd6d7099d2',
#    'c81068b46063a2cf01d764b222ae3ea7',
#    '81be4043affd0663ce9a8a47c2a01ac6',
#    'a044856cedc1b9cde89f0bab7797965e',
#    'f85a6a79c632d6605f7148418aa3853e',
#    'ba008a1c2174f768c5b601daf82af069',
#    '721c4637983a9d16431ba3a4c8e0874e'],
#   'installment_plans': None,
#   'is_adult': None,
#   'is_category_failed': False,
#   'is_cc_installment_payment_eligible': False,
#   'is_installment_payment_eligible': False,
#   'is_non_cc_installment_payment_eligible': False,
#   'is_official_shop': False,
#   'is_pre_order': False,
#   'is_shopee_verified': False,
#   'item_status': 'normal',
#   'itemid': 846184303,
#   'liked': False,
#   'liked_count': 21,
#   'models': [{'ctime': 1516275724,
#     'currency': 'TWD',
#     'extinfo': {'stockout_time': 0},
#     'itemid': 846184303,
#     'modelid': 731703017,
#     'mtime': 1520235146,
#     'name': 'M4PLUS(主機+電源天線)',
#     'price': 32000000,
#     'price_before_discount': 0,
#     'promotionid': 0,
#     'rebate_price': 0,
#     'sku': '',
#     'sold': 44,
#     'status': 1,
#     'stock': 703},
#    {'ctime': 1516275724,
#     'currency': 'TWD',
#     'extinfo': {'stockout_time': 0},
#     'itemid': 846184303,
#     'modelid': 731703018,
#     'mtime': 1516360890,
#     'name': 'HDMI公母延長線50CM強烈建議加購',
#     'price': 6500000,
#     'price_before_discount': 0,
#     'promotionid': 0,
#     'rebate_price': 0,
#     'sku': '',
#     'sold': 12,
#     'status': 1,
#     'stock': 804}],
#   'name': '新款 M4 + RK3036晶片 AnyCast 手機電視棒 csr MIRACAST MHL 藍芽耳機 m2 plus',
#   'offer_count': 0,
#   'price': 6500000,
#   'price_before_discount': 0,
#   'price_max': 32000000,
#   'price_max_before_discount': -1,
#   'price_min': 6500000,
#   'price_min_before_discount': -1,
#   'rating_count': [31, 0, 0, 0, 1, 30],
#   'rating_star': 4.967741935483871,
#   'raw_discount': None,
#   'rcount_with_context': 18,
#   'rcount_with_image': 0,
#   'service_by_shopee_flag': 0,
#   'shopid': 4827179,
#   'show_discount': 0,
#   'show_free_shipping': False,
#   'sold': 38,
#   'stock': 1507,
#   'sub_catid': 297,
#   'third_catid': 5796,
#   'videos': [],
#   'wholesale_tier_list': []},
#  {'attributes': [],
#   'brand': 'SUGAR(糖果手機)',
#   'bundle_deal_info': None,
#   'can_use_bundle_deal': False,
#   'can_use_wholesale': False,
#   'catid': 70,
#   'cb_option': 0,
#   'cmt_count': 118,
#   'coin_earn_items': None,
#   'coin_spend_cash_unit': None,
#   'condition': 1,
#   'currency': 'TWD',
#   'description': None,
#   'discount': None,
#   'estimated_days': 3,
#   'flash_sale': None,
#   'free_return_day': 15,
#   'has_lowest_price_guarantee': False,
#   'hashtag_list': [],
#   'image': '8e93e86fd64ac2a031c466a61492525a',
#   'image_list': ['8e93e86fd64ac2a031c466a61492525a',
#    'd81f18b65e297f1e53d468c78e27e852',
#    '889fc29a5f7130a25da83c6f65f48cd6',
#    '02d6e54a6c5ec6b93dfb9d64a9540061'],
#   'installment_plans': None,
#   'is_adult': None,
#   'is_category_failed': False,
#   'is_cc_installment_payment_eligible': False,
#   'is_installment_payment_eligible': False,
#   'is_non_cc_installment_payment_eligible': False,
#   'is_official_shop': False,
#   'is_pre_order': False,
#   'is_shopee_verified': False,
#   'item_status': 'normal',
#   'itemid': 802316023,
#   'liked': False,
#   'liked_count': 265,
#   'models': [{'ctime': 1519969780,
#     'currency': 'TWD',
#     'extinfo': {'stockout_time': 0},
#     'itemid': 802316023,
#     'modelid': 799413715,
#     'mtime': 1520056814,
#     'name': '摩卡灰',
#     'price': 380000000,
#     'price_before_discount': 0,
#     'promotionid': 0,
#     'rebate_price': 0,
#     'sold': 3,
#     'status': 1,
#     'stock': 9},
#    {'ctime': 1519969780,
#     'currency': 'TWD',
#     'extinfo': {'stockout_time': 0},
#     'itemid': 802316023,
#     'modelid': 799413716,
#     'mtime': 1520056814,
#     'name': '摩卡灰+玻璃保護貼',
#     'price': 390000000,
#     'price_before_discount': 0,
#     'promotionid': 0,
#     'rebate_price': 0,
#     'sold': 3,
#     'status': 1,
#     'stock': 7}],
#   'name': '（現貨）SUGAR 糖果手機 y7 MAX(全新未拆封) 香檳金/摩卡灰（贈原廠側掀皮套、清水套、軟性螢幕保護貼）',
#   'offer_count': 0,
#   'price': 380000000,
#   'price_before_discount': 0,
#   'price_max': 390000000,
#   'price_max_before_discount': -1,
#   'price_min': 380000000,
#   'price_min_before_discount': -1,
#   'rating_count': [96, 0, 0, 0, 3, 93],
#   'rating_star': 4.96875,
#   'raw_discount': None,
#   'rcount_with_context': 72,
#   'rcount_with_image': 1,
#   'service_by_shopee_flag': 0,
#   'shopid': 15171156,
#   'show_discount': 0,
#   'show_free_shipping': False,
#   'sold': 124,
#   'stock': 16,
#   'sub_catid': 2609,
#   'third_catid': 5809,
#   'videos': [],
#   'wholesale_tier_list': []},
#  {'attributes': [],
#   'brand': 'SUGAR(糖果手機)',
#   'bundle_deal_info': None,
#   'can_use_bundle_deal': False,
#   'can_use_wholesale': False,
#   'catid': 70,
#   'cb_option': 0,
#   'cmt_count': 30,
#   'coin_earn_items': None,
#   'coin_spend_cash_unit': None,
#   'condition': 1,
#   'currency': 'TWD',
#   'description': None,
#   'discount': None,
#   'estimated_days': 3,
#   'flash_sale': None,
#   'free_return_day': 15,
#   'has_lowest_price_guarantee': False,
#   'hashtag_list': [],
#   'image': '3bcf59c85f9452b2fe39c04c17dd2700',
#   'image_list': ['3bcf59c85f9452b2fe39c04c17dd2700'],
#   'installment_plans': None,
#   'is_adult': None,
#   'is_category_failed': False,
#   'is_cc_installment_payment_eligible': False,
#   'is_installment_payment_eligible': False,
#   'is_non_cc_installment_payment_eligible': False,
#   'is_official_shop': False,
#   'is_pre_order': False,
#   'is_shopee_verified': False,
#   'item_status': 'normal',
#   'itemid': 888957119,
#   'liked': False,
#   'liked_count': 33,
#   'models': [{'ctime': 1517569661,
#     'currency': 'TWD',
#     'extinfo': {'stockout_time': 1518666689},
#     'itemid': 888957119,
#     'modelid': 767073295,
#     'mtime': 1518666689,
#     'name': '灰色',
#     'price': 398000000,
#     'price_before_discount': 0,
#     'promotionid': 0,
#     'rebate_price': 0,
#     'sku': '',
#     'sold': 3,
#     'status': 1,
#     'stock': 0},
#    {'ctime': 1517569661,
#     'currency': 'TWD',
#     'extinfo': {'stockout_time': 0},
#     'itemid': 888957119,
#     'modelid': 767073296,
#     'mtime': 1521021212,
#     'name': '紅色',
#     'price': 398000000,
#     'price_before_discount': 0,
#     'promotionid': 0,
#     'rebate_price': 0,
#     'sku': '',
#     'sold': 6,
#     'status': 1,
#     'stock': 10},
#    {'ctime': 1517569661,
#     'currency': 'TWD',
#     'extinfo': {'stockout_time': 0},
#     'itemid': 888957119,
#     'modelid': 767073297,
#     'mtime': 1521021212,
#     'name': '金色',
#     'price': 398000000,
#     'price_before_discount': 0,
#     'promotionid': 0,
#     'rebate_price': 0,
#     'sku': '',
#     'sold': 11,
#     'status': 1,
#     'stock': 10}],
#   'name': '全新未拆封 保固一年 糖果手機 SUGAR C11s 支援4G + 3G 雙卡雙待 5.7 吋全螢幕設計 智慧型手機',
#   'offer_count': 0,
#   'price': 398000000,
#   'price_before_discount': 0,
#   'price_max': 398000000,
#   'price_max_before_discount': -1,
#   'price_min': 398000000,
#   'price_min_before_discount': -1,
#   'rating_count': [14, 0, 0, 0, 0, 14],
#   'rating_star': 5.0,
#   'raw_discount': None,
#   'rcount_with_context': 12,
#   'rcount_with_image': 0,
#   'service_by_shopee_flag': 0,
#   'shopid': 1580315,
#   'show_discount': 0,
#   'show_free_shipping': False,
#   'sold': 20,
#   'stock': 20,
#   'sub_catid': 2610,
#   'third_catid': 5808,
#   'videos': [],
#   'wholesale_tier_list': []},
#  {'attributes': [],
#   'brand': 'SUGAR(糖果手機)',
#   'bundle_deal_info': None,
#   'can_use_bundle_deal': False,
#   'can_use_wholesale': False,
#   'catid': 70,
#   'cb_option': 0,
#   'cmt_count': 14,
#   'coin_earn_items': None,
#   'coin_spend_cash_unit': None,
#   'condition': 1,
#   'currency': 'TWD',
#   'description': None,
#   'discount': None,
#   'estimated_days': 3,
#   'flash_sale': None,
#   'free_return_day': 15,
#   'has_lowest_price_guarantee': False,
#   'hashtag_list': [],
#   'image': 'e6842d8b5855bce53bc52413dea1386c',
#   'image_list': ['e6842d8b5855bce53bc52413dea1386c',
#    '62c90d21a3e574cf2d5d4def1538722c',
#    '0269246e5f7fc2dc376675e57411b7f2'],
#   'installment_plans': None,
#   'is_adult': None,
#   'is_category_failed': False,
#   'is_cc_installment_payment_eligible': False,
#   'is_installment_payment_eligible': False,
#   'is_non_cc_installment_payment_eligible': False,
#   'is_official_shop': False,
#   'is_pre_order': False,
#   'is_shopee_verified': True,
#   'item_status': 'normal',
#   'itemid': 815532393,
#   'liked': False,
#   'liked_count': 81,
#   'models': [{'ctime': 1515342271,
#     'currency': 'TWD',
#     'extinfo': {'holiday_mode_old_stock': 0, 'stockout_time': 0},
#     'itemid': 815532393,
#     'modelid': 699626503,
#     'mtime': 1520924424,
#     'name': '紅',
#     'price': 399900000,
#     'price_before_discount': 0,
#     'promotionid': 0,
#     'rebate_price': 0,
#     'sold': 3,
#     'status': 1,
#     'stock': 1},
#    {'ctime': 1515342271,
#     'currency': 'TWD',
#     'extinfo': {'holiday_mode_old_stock': 0, 'stockout_time': 0},
#     'itemid': 815532393,
#     'modelid': 699626504,
#     'mtime': 1520924424,
#     'name': '金',
#     'price': 399900000,
#     'price_before_discount': 0,
#     'promotionid': 0,
#     'rebate_price': 0,
#     'sold': 12,
#     'status': 1,
#     'stock': 5},
#    {'ctime': 1515342271,
#     'currency': 'TWD',
#     'extinfo': {'stockout_time': 1520238641},
#     'itemid': 815532393,
#     'modelid': 699626505,
#     'mtime': 1519299171,
#     'name': '灰',
#     'price': 409900000,
#     'price_before_discount': 0,
#     'promotionid': 0,
#     'rebate_price': 0,
#     'sold': 5,
#     'status': 1,
#     'stock': 0}],
#   'name': '全新保1年 Sugar C11s 5.7吋 3+32G 雙卡 4G+3G 貨到付款 超商取貨付款 現貨 糖果手機',
#   'offer_count': 0,
#   'price': 399900000,
#   'price_before_discount': 0,
#   'price_max': 399900000,
#   'price_max_before_discount': -1,
#   'price_min': 399900000,
#   'price_min_before_discount': -1,
#   'rating_count': [13, 0, 0, 0, 0, 13],
#   'rating_star': 5.0,
#   'raw_discount': None,
#   'rcount_with_context': 10,
#   'rcount_with_image': 1,
#   'service_by_shopee_flag': 0,
#   'shopid': 20990061,
#   'show_discount': 0,
#   'show_free_shipping': False,
#   'sold': 16,
#   'stock': 6,
#   'sub_catid': 2609,
#   'third_catid': 5809,
#   'videos': [],
#   'wholesale_tier_list': []},
#  {'attributes': [],
#   'brand': 'SUGAR(糖果手機)',
#   'bundle_deal_info': None,
#   'can_use_bundle_deal': False,
#   'can_use_wholesale': False,
#   'catid': 70,
#   'cb_option': 0,
#   'cmt_count': 12,
#   'coin_earn_items': None,
#   'coin_spend_cash_unit': None,
#   'condition': 1,
#   'currency': 'TWD',
#   'description': None,
#   'discount': None,
#   'estimated_days': 3,
#   'flash_sale': None,
#   'free_return_day': 15,
#   'has_lowest_price_guarantee': False,
#   'hashtag_list': [],
#   'image': 'b237d244652d869507331eaad954283d',
#   'image_list': ['b237d244652d869507331eaad954283d'],
#   'installment_plans': None,
#   'is_adult': None,
#   'is_category_failed': False,
#   'is_cc_installment_payment_eligible': False,
#   'is_installment_payment_eligible': False,
#   'is_non_cc_installment_payment_eligible': False,
#   'is_official_shop': False,
#   'is_pre_order': False,
#   'is_shopee_verified': False,
#   'item_status': 'normal',
#   'itemid': 794487371,
#   'liked': False,
#   'liked_count': 46,
#   'models': [{'ctime': 1518909092,
#     'currency': 'TWD',
#     'extinfo': {'stockout_time': 0},
#     'itemid': 794487371,
#     'modelid': 782108252,
#     'mtime': 1521028342,
#     'name': '鐵灰+玻保',
#     'price': 275000000,
#     'price_before_discount': 0,
#     'promotionid': 0,
#     'rebate_price': 0,
#     'sold': 11,
#     'status': 1,
#     'stock': 4},
#    {'ctime': 1520174319,
#     'currency': 'TWD',
#     'extinfo': {'stockout_time': 0},
#     'itemid': 794487371,
#     'modelid': 805346178,
#     'mtime': 1521028342,
#     'name': '金',
#     'price': 320000000,
#     'price_before_discount': 0,
#     'promotionid': 0,
#     'rebate_price': 0,
#     'sold': 1,
#     'status': 1,
#     'stock': 1}],
#   'name': '現貨~全新未拆~SUGAR Y7 MAX(3G /16G)~4G全頻~贈原廠皮套+保護套~台中彰化可面交',
#   'offer_count': 0,
#   'price': 275000000,
#   'price_before_discount': 0,
#   'price_max': 320000000,
#   'price_max_before_discount': -1,
#   'price_min': 275000000,
#   'price_min_before_discount': -1,
#   'rating_count': [12, 0, 0, 0, 1, 11],
#   'rating_star': 4.916666666666667,
#   'raw_discount': None,
#   'rcount_with_context': 7,
#   'rcount_with_image': 0,
#   'service_by_shopee_flag': 0,
#   'shopid': 17371416,
#   'show_discount': 0,
#   'show_free_shipping': False,
#   'sold': 16,
#   'stock': 5,
#   'sub_catid': 2609,
#   'third_catid': 5809,
#   'videos': [],
#   'wholesale_tier_list': []},
#  {'attributes': [],
#   'brand': 'SUGAR(糖果手機)',
#   'bundle_deal_info': None,
#   'can_use_bundle_deal': False,
#   'can_use_wholesale': False,
#   'catid': 70,
#   'cb_option': 0,
#   'cmt_count': 35,
#   'coin_earn_items': None,
#   'coin_spend_cash_unit': None,
#   'condition': 1,
#   'currency': 'TWD',
#   'description': None,
#   'discount': '8.5',
#   'estimated_days': 7,
#   'flash_sale': None,
#   'free_return_day': 15,
#   'has_lowest_price_guarantee': False,
#   'hashtag_list': [],
#   'image': 'b2129a09dd932abac0be1735382a9afa',
#   'image_list': ['b2129a09dd932abac0be1735382a9afa',
#    'd854920242b979e7e6a36e8e3a5c5cb8',
#    '32d31eb6758c0a48376107a682bf4853',
#    '923175bc6f169c5ecdfc1373611791ce',
#    '45f41e394d915057c29ba88e086b8584',
#    '91e7d368350ae2d4048d526841ca8ac9',
#    'fdf7a3721a205944d8e06b69fb3395f7',
#    '6aa3af9ca0ae3a2ef0926e06c07f0ae8',
#    '2ba363acda93d7bb773af744852b84b7'],
#   'installment_plans': None,
#   'is_adult': None,
#   'is_category_failed': False,
#   'is_cc_installment_payment_eligible': False,
#   'is_installment_payment_eligible': False,
#   'is_non_cc_installment_payment_eligible': False,
#   'is_official_shop': True,
#   'is_pre_order': True,
#   'is_shopee_verified': True,
#   'item_status': 'normal',
#   'itemid': 132018096,
#   'liked': False,
#   'liked_count': 326,
#   'models': [{'ctime': 1514338418,
#     'currency': 'TWD',
#     'extinfo': {'has_shopee_promo': False,
#      'promo_source': 1,
#      'seller_promotion_refresh_time': 1535043602,
#      'stockout_time': 0},
#     'itemid': 132018096,
#     'modelid': 668383542,
#     'mtime': 1521022616,
#     'name': '手機',
#     'price': 329000000,
#     'price_before_discount': 388000000,
#     'promotionid': 1001968330,
#     'rebate_price': 0,
#     'sku': '',
#     'sold': 15,
#     'status': 1,
#     'stock': 2}],
#   'name': '【新年換新機】鑲鑽/美顏/美肌 糖果手機 SUGAR C7 4G LTE 3G+32G 大容量 5吋螢幕 指紋辨識 免運',
#   'offer_count': 0,
#   'price': 329000000,
#   'price_before_discount': 388000000,
#   'price_max': 329000000,
#   'price_max_before_discount': 388000000,
#   'price_min': 329000000,
#   'price_min_before_discount': 388000000,
#   'rating_count': [22, 0, 0, 0, 0, 22],
#   'rating_star': 5.0,
#   'raw_discount': 15,
#   'rcount_with_context': 16,
#   'rcount_with_image': 0,
#   'service_by_shopee_flag': 0,
#   'shopid': 540615,
#   'show_discount': 15,
#   'show_free_shipping': True,
#   'sold': 13,
#   'stock': 2,
#   'sub_catid': 2609,
#   'third_catid': 5809,
#   'videos': [],
#   'wholesale_tier_list': []},
#  {'attributes': [],
#   'brand': 'SUGAR(糖果手機)',
#   'bundle_deal_info': None,
#   'can_use_bundle_deal': False,
#   'can_use_wholesale': False,
#   'catid': 70,
#   'cb_option': 0,
#   'cmt_count': 10,
#   'coin_earn_items': None,
#   'coin_spend_cash_unit': None,
#   'condition': 1,
#   'currency': 'TWD',
#   'description': None,
#   'discount': None,
#   'estimated_days': 3,
#   'flash_sale': None,
#   'free_return_day': 15,
#   'has_lowest_price_guarantee': False,
#   'hashtag_list': [],
#   'image': '400d3e282d60be99766e48337ad2d90e',
#   'image_list': ['400d3e282d60be99766e48337ad2d90e',
#    'c3ad00dd03dfab36177468f43e1bd534',
#    '58defd59e1c08cc13b9b2a5ec89ab099',
#    'fcd0cdca91aaf0f289d9ef34e8696da6',
#    '8d8f7f71a1c335db1e9b9d3648ddfcdb',
#    '87b2e95c4d9d3752b045097323a22c47',
#    '1a80b87f3107df05cb63fbf7277365e5',
#    '49d640964c86b0b5ba91d3398ad505b7'],
#   'installment_plans': None,
#   'is_adult': None,
#   'is_category_failed': False,
#   'is_cc_installment_payment_eligible': False,
#   'is_installment_payment_eligible': False,
#   'is_non_cc_installment_payment_eligible': False,
#   'is_official_shop': False,
#   'is_pre_order': False,
#   'is_shopee_verified': False,
#   'item_status': 'normal',
#   'itemid': 621230590,
#   'liked': False,
#   'liked_count': 17,
#   'models': [{'ctime': 1508902656,
#     'currency': 'TWD',
#     'extinfo': {'stockout_time': 0},
#     'itemid': 621230590,
#     'modelid': 462824150,
#     'mtime': 1519108432,
#     'name': '金色(全新開發票)+送三好禮',
#     'price': 550000000,
#     'price_before_discount': 0,
#     'promotionid': 0,
#     'rebate_price': 0,
#     'sku': '',
#     'sold': 12,
#     'status': 1,
#     'stock': 6},
#    {'ctime': 1508902656,
#     'currency': 'TWD',
#     'extinfo': {'stockout_time': 1519007370},
#     'itemid': 621230590,
#     'modelid': 462824151,
#     'mtime': 1519007370,
#     'name': '紅色(全新開發票)+送三好禮',
#     'price': 550000000,
#     'price_before_discount': 0,
#     'promotionid': 0,
#     'rebate_price': 0,
#     'sku': '',
#     'sold': 3,
#     'status': 1,
#     'stock': 0}],
#   'name': '(送好禮)(全新開發票)【SUGAR C11】全螢幕手機 2000萬 雙鏡自拍 120度超廣角',
#   'offer_count': 0,
#   'price': 550000000,
#   'price_before_discount': 0,
#   'price_max': 550000000,
#   'price_max_before_discount': -1,
#   'price_min': 550000000,
#   'price_min_before_discount': -1,
#   'rating_count': [7, 0, 0, 0, 0, 7],
#   'rating_star': 5.0,
#   'raw_discount': None,
#   'rcount_with_context': 4,
#   'rcount_with_image': 0,
#   'service_by_shopee_flag': 0,
#   'shopid': 22204594,
#   'show_discount': 0,
#   'show_free_shipping': True,
#   'sold': 9,
#   'stock': 6,
#   'sub_catid': 2609,
#   'third_catid': 5809,
#   'videos': [],
#   'wholesale_tier_list': []},
#  {'attributes': [],
#   'brand': 'SUGAR(糖果手機)',
#   'bundle_deal_info': None,
#   'can_use_bundle_deal': False,
#   'can_use_wholesale': False,
#   'catid': 70,
#   'cb_option': 0,
#   'cmt_count': 7,
#   'coin_earn_items': None,
#   'coin_spend_cash_unit': None,
#   'condition': 1,
#   'currency': 'TWD',
#   'description': None,
#   'discount': None,
#   'estimated_days': 3,
#   'flash_sale': None,
#   'free_return_day': 15,
#   'has_lowest_price_guarantee': False,
#   'hashtag_list': [],
#   'image': '16b1a115a25a3251f3d4dbd64e65c543',
#   'image_list': ['16b1a115a25a3251f3d4dbd64e65c543',
#    '4458536f2a1757de97559f4a0d5c093f',
#    '8a05fffd6bedebef07d094b8daea8ba5',
#    '73e3174deffb4e3cb1791455e1b1663c'],
#   'installment_plans': None,
#   'is_adult': None,
#   'is_category_failed': False,
#   'is_cc_installment_payment_eligible': False,
#   'is_installment_payment_eligible': False,
#   'is_non_cc_installment_payment_eligible': False,
#   'is_official_shop': False,
#   'is_pre_order': False,
#   'is_shopee_verified': False,
#   'item_status': 'normal',
#   'itemid': 760203527,
#   'liked': False,
#   'liked_count': 33,
#   'models': [{'ctime': 1518418917,
#     'currency': 'TWD',
#     'extinfo': {'stockout_time': 0},
#     'itemid': 760203527,
#     'modelid': 778324153,
#     'mtime': 1520993376,
#     'name': '紅色',
#     'price': 390000000,
#     'price_before_discount': 0,
#     'promotionid': 0,
#     'rebate_price': 0,
#     'sku': '',
#     'sold': 4,
#     'status': 1,
#     'stock': 10},
#    {'ctime': 1518418917,
#     'currency': 'TWD',
#     'extinfo': {'stockout_time': 0},
#     'itemid': 760203527,
#     'modelid': 778324154,
#     'mtime': 1520993376,
#     'name': '金色',
#     'price': 390000000,
#     'price_before_discount': 0,
#     'promotionid': 0,
#     'rebate_price': 0,
#     'sku': '',
#     'sold': 3,
#     'status': 1,
#     'stock': 10},
#    {'ctime': 1518418917,
#     'currency': 'TWD',
#     'itemid': 760203527,
#     'modelid': 778324155,
#     'mtime': 1520993376,
#     'name': '灰色',
#     'price': 390000000,
#     'price_before_discount': 0,
#     'promotionid': 0,
#     'rebate_price': 0,
#     'sku': '',
#     'sold': 0,
#     'status': 1,
#     'stock': 0}],
#   'name': '『百家流通3C』SUGAR C11s 3GB RAM / 32GB ROM',
#   'offer_count': 0,
#   'price': 390000000,
#   'price_before_discount': 0,
#   'price_max': 390000000,
#   'price_max_before_discount': -1,
#   'price_min': 390000000,
#   'price_min_before_discount': -1,
#   'rating_count': [7, 0, 0, 0, 0, 7],
#   'rating_star': 5.0,
#   'raw_discount': None,
#   'rcount_with_context': 4,
#   'rcount_with_image': 0,
#   'service_by_shopee_flag': 0,
#   'shopid': 16295631,
#   'show_discount': 0,
#   'show_free_shipping': False,
#   'sold': 8,
#   'stock': 20,
#   'sub_catid': 2609,
#   'third_catid': 5809,
#   'videos': [],
#   'wholesale_tier_list': []},
#  {'attributes': [],
#   'brand': 'SUGAR(糖果手機)',
#   'bundle_deal_info': None,
#   'can_use_bundle_deal': False,
#   'can_use_wholesale': False,
#   'catid': 70,
#   'cb_option': 0,
#   'cmt_count': 23,
#   'coin_earn_items': None,
#   'coin_spend_cash_unit': None,
#   'condition': 1,
#   'currency': 'TWD',
#   'description': None,
#   'discount': None,
#   'estimated_days': 7,
#   'flash_sale': None,
#   'free_return_day': 15,
#   'has_lowest_price_guarantee': False,
#   'hashtag_list': [],
#   'image': '5c5c8251fa8ef42c34b8df65fa5cd328',
#   'image_list': ['5c5c8251fa8ef42c34b8df65fa5cd328',
#    '58027c055f321189fd5b778e0061f69d',
#    'd4e8fc75466afb345f8d9f3929612996',
#    '477c91213113bbe9d049c525fd4cdc56',
#    '088cbf83c033e4e4deb76d57ab8e3127',
#    'e80d3a53859e3502435f198683caf0ac',
#    'b24dfd16a70617c24ac5c329de65fbb1',
#    'aff21eaa2848569185da603b40d4cf95'],
#   'installment_plans': None,
#   'is_adult': None,
#   'is_category_failed': False,
#   'is_cc_installment_payment_eligible': False,
#   'is_installment_payment_eligible': False,
#   'is_non_cc_installment_payment_eligible': False,
#   'is_official_shop': False,
#   'is_pre_order': True,
#   'is_shopee_verified': True,
#   'item_status': 'normal',
#   'itemid': 622883247,
#   'liked': False,
#   'liked_count': 47,
#   'models': [{'ctime': 1508932811,
#     'currency': 'TWD',
#     'extinfo': {'stockout_time': 0},
#     'itemid': 622883247,
#     'modelid': 464477346,
#     'mtime': 1519888960,
#     'name': '金',
#     'price': 400000000,
#     'price_before_discount': 0,
#     'promotionid': 0,
#     'rebate_price': 0,
#     'sku': '',
#     'sold': 7,
#     'status': 1,
#     'stock': 1},
#    {'ctime': 1513147624,
#     'currency': 'TWD',
#     'extinfo': {'stockout_time': 1519946540},
#     'itemid': 622883247,
#     'modelid': 624277025,
#     'mtime': 1519888960,
#     'name': '灰',
#     'price': 400000000,
#     'price_before_discount': 0,
#     'promotionid': 0,
#     'rebate_price': 0,
#     'sku': '',
#     'sold': 1,
#     'status': 1,
#     'stock': 0},
#    {'ctime': 1513147624,
#     'currency': 'TWD',
#     'extinfo': {'stockout_time': 0},
#     'itemid': 622883247,
#     'modelid': 624277026,
#     'mtime': 1520135806,
#     'name': '紅',
#     'price': 400000000,
#     'price_before_discount': 0,
#     'promotionid': 0,
#     'rebate_price': 0,
#     'sku': '',
#     'sold': 7,
#     'status': 1,
#     'stock': 4}],
#   'name': '《TDC》SUGAR 糖果 法國 C11S LTE 5.7 吋 全螢幕 指紋辨識 雙卡 3G/32G【金 灰 紅】供應中',
#   'offer_count': 0,
#   'price': 400000000,
#   'price_before_discount': 0,
#   'price_max': 400000000,
#   'price_max_before_discount': -1,
#   'price_min': 400000000,
#   'price_min_before_discount': -1,
#   'rating_count': [7, 0, 0, 0, 1, 6],
#   'rating_star': 4.857142857142857,
#   'raw_discount': None,
#   'rcount_with_context': 4,
#   'rcount_with_image': 0,
#   'service_by_shopee_flag': 0,
#   'shopid': 12448,
#   'show_discount': 0,
#   'show_free_shipping': False,
#   'sold': 7,
#   'stock': 5,
#   'sub_catid': 2609,
#   'third_catid': 5809,
#   'videos': [],
#   'wholesale_tier_list': []},
#  {'attributes': [],
#   'brand': 'SUGAR(糖果手機)',
#   'bundle_deal_info': None,
#   'can_use_bundle_deal': False,
#   'can_use_wholesale': False,
#   'catid': 70,
#   'cb_option': 0,
#   'cmt_count': 0,
#   'coin_earn_items': None,
#   'coin_spend_cash_unit': None,
#   'condition': 1,
#   'currency': 'TWD',
#   'description': None,
#   'discount': None,
#   'estimated_days': 7,
#   'flash_sale': None,
#   'free_return_day': 15,
#   'has_lowest_price_guarantee': False,
#   'hashtag_list': [],
#   'image': 'd03e4dc2b658d4bd02f1b6534fd69370',
#   'image_list': ['d03e4dc2b658d4bd02f1b6534fd69370',
#    'bb807c5124dcd09669029c9e9dc3cc4d',
#    '7055a9eab2f839254b31f51546c548fc',
#    '46cf112c95b10cf05d8159138e80dc2a',
#    '3e0df224985b8f45cd4d2213e15b25ef',
#    'c866dfe5b8be67d6c0d4b3e4dd985a7c'],
#   'installment_plans': None,
#   'is_adult': None,
#   'is_category_failed': False,
#   'is_cc_installment_payment_eligible': False,
#   'is_installment_payment_eligible': False,
#   'is_non_cc_installment_payment_eligible': False,
#   'is_official_shop': False,
#   'is_pre_order': True,
#   'is_shopee_verified': False,
#   'item_status': 'normal',
#   'itemid': 937617153,
#   'liked': False,
#   'liked_count': 11,
#   'models': [{'ctime': 1519368215,
#     'currency': 'TWD',
#     'extinfo': {'stockout_time': 0},
#     'itemid': 937617153,
#     'modelid': 786741411,
#     'mtime': 1520948697,
#     'name': '太空灰',
#     'price': 290000000,
#     'price_before_discount': 0,
#     'promotionid': 0,
#     'rebate_price': 0,
#     'sold': 1,
#     'status': 1,
#     'stock': 5}],
#   'name': '💯現貨🎉SUGAR Y7 MAX',
#   'offer_count': 0,
#   'price': 290000000,
#   'price_before_discount': 0,
#   'price_max': 290000000,
#   'price_max_before_discount': -1,
#   'price_min': 290000000,
#   'price_min_before_discount': -1,
#   'rating_count': [0, 0, 0, 0, 0, 0],
#   'rating_star': 0,
#   'raw_discount': None,
#   'rcount_with_context': 0,
#   'rcount_with_image': 0,
#   'service_by_shopee_flag': 0,
#   'shopid': 4975228,
#   'show_discount': 0,
#   'show_free_shipping': False,
#   'sold': 5,
#   'stock': 5,
#   'sub_catid': 2609,
#   'third_catid': 5809,
#   'videos': [],
#   'wholesale_tier_list': []},
#  {'attributes': [],
#   'brand': None,
#   'bundle_deal_info': None,
#   'can_use_bundle_deal': False,
#   'can_use_wholesale': False,
#   'catid': 70,
#   'cb_option': 0,
#   'cmt_count': 4,
#   'coin_earn_items': None,
#   'coin_spend_cash_unit': None,
#   'condition': 1,
#   'currency': 'TWD',
#   'description': None,
#   'discount': None,
#   'estimated_days': 3,
#   'flash_sale': None,
#   'free_return_day': 15,
#   'has_lowest_price_guarantee': False,
#   'hashtag_list': [],
#   'image': '26ad46dec0745359cd0f8e8a9025258f',
#   'image_list': ['26ad46dec0745359cd0f8e8a9025258f'],
#   'installment_plans': None,
#   'is_adult': None,
#   'is_category_failed': False,
#   'is_cc_installment_payment_eligible': False,
#   'is_installment_payment_eligible': False,
#   'is_non_cc_installment_payment_eligible': False,
#   'is_official_shop': False,
#   'is_pre_order': False,
#   'is_shopee_verified': False,
#   'item_status': 'normal',
#   'itemid': 888979052,
#   'liked': False,
#   'liked_count': 15,
#   'models': [{'ctime': 1517570171,
#     'currency': 'TWD',
#     'extinfo': {'stockout_time': 0},
#     'itemid': 888979052,
#     'modelid': 767086731,
#     'mtime': 1517570171,
#     'name': '藍色',
#     'price': 389000000,
#     'price_before_discount': 0,
#     'promotionid': 0,
#     'rebate_price': 0,
#     'sold': 1,
#     'status': 1,
#     'stock': 9},
#    {'ctime': 1517570171,
#     'currency': 'TWD',
#     'extinfo': {'stockout_time': 0},
#     'itemid': 888979052,
#     'modelid': 767086732,
#     'mtime': 1517570171,
#     'name': '金色',
#     'price': 389000000,
#     'price_before_discount': 0,
#     'promotionid': 0,
#     'rebate_price': 0,
#     'sold': 3,
#     'status': 1,
#     'stock': 6}],
#   'name': 'SUGAR Y12 5.45吋 3G/32G 雙卡雙待 鏡頭800萬畫素 三鏡美拍 拍照留聲 萌拍特效 智慧型手機',
#   'offer_count': 0,
#   'price': 389000000,
#   'price_before_discount': 0,
#   'price_max': 389000000,
#   'price_max_before_discount': -1,
#   'price_min': 389000000,
#   'price_min_before_discount': -1,
#   'rating_count': [4, 0, 0, 0, 0, 4],
#   'rating_star': 5.0,
#   'raw_discount': None,
#   'rcount_with_context': 4,
#   'rcount_with_image': 0,
#   'service_by_shopee_flag': 0,
#   'shopid': 1580315,
#   'show_discount': 0,
#   'show_free_shipping': True,
#   'sold': 5,
#   'stock': 15,
#   'sub_catid': 2610,
#   'third_catid': 5808,
#   'videos': [],
#   'wholesale_tier_list': []},
#  {'attributes': [],
#   'brand': 'SUGAR(糖果手機)',
#   'bundle_deal_info': None,
#   'can_use_bundle_deal': False,
#   'can_use_wholesale': False,
#   'catid': 70,
#   'cb_option': 0,
#   'cmt_count': 3,
#   'coin_earn_items': None,
#   'coin_spend_cash_unit': None,
#   'condition': 1,
#   'currency': 'TWD',
#   'description': None,
#   'discount': None,
#   'estimated_days': 3,
#   'flash_sale': None,
#   'free_return_day': 15,
#   'has_lowest_price_guarantee': False,
#   'hashtag_list': [],
#   'image': 'f19f2cdec4214b65719f905ba6a8ba45',
#   'image_list': ['f19f2cdec4214b65719f905ba6a8ba45',
#    '00165fe1b7ceb8b5bd5d9f2ddc8f9d89',
#    'de30f85691470b2977fdf39ccba2c7e9',
#    '7aa2dff7b439d7c809def4c9690507ab',
#    '00d84745e0ecb4bcca170fe1ca092bfd',
#    '74dee7af7b6073a92eab7016b0976076'],
#   'installment_plans': None,
#   'is_adult': None,
#   'is_category_failed': False,
#   'is_cc_installment_payment_eligible': False,
#   'is_installment_payment_eligible': False,
#   'is_non_cc_installment_payment_eligible': False,
#   'is_official_shop': False,
#   'is_pre_order': False,
#   'is_shopee_verified': False,
#   'item_status': 'normal',
#   'itemid': 780979340,
#   'liked': False,
#   'liked_count': 5,
#   'models': [{'ctime': 1514009830,
#     'currency': 'TWD',
#     'extinfo': {'stockout_time': 0},
#     'itemid': 780979340,
#     'modelid': 657262635,
#     'mtime': 1521008683,
#     'name': '香檳金',
#     'price': 399000000,
#     'price_before_discount': 0,
#     'promotionid': 0,
#     'rebate_price': 0,
#     'sku': '',
#     'sold': 1,
#     'status': 1,
#     'stock': 2},
#    {'ctime': 1514009830,
#     'currency': 'TWD',
#     'extinfo': {'stockout_time': 0},
#     'itemid': 780979340,
#     'modelid': 657262636,
#     'mtime': 1521008683,
#     'name': '玫瑰金',
#     'price': 399000000,
#     'price_before_discount': 0,
#     'promotionid': 0,
#     'rebate_price': 0,
#     'sku': '',
#     'sold': 4,
#     'status': 1,
#     'stock': 3}],
#   'name': '【限時下殺】SUGAR F7 mini 5吋尚手機',
#   'offer_count': 0,
#   'price': 399000000,
#   'price_before_discount': 0,
#   'price_max': 399000000,
#   'price_max_before_discount': -1,
#   'price_min': 399000000,
#   'price_min_before_discount': -1,
#   'rating_count': [3, 0, 0, 0, 0, 3],
#   'rating_star': 5.0,
#   'raw_discount': None,
#   'rcount_with_context': 3,
#   'rcount_with_image': 1,
#   'service_by_shopee_flag': 0,
#   'shopid': 176939,
#   'show_discount': 0,
#   'show_free_shipping': False,
#   'sold': 5,
#   'stock': 5,
#   'sub_catid': 2609,
#   'third_catid': 5809,
#   'videos': [],
#   'wholesale_tier_list': []},
#  {'attributes': [],
#   'brand': 'SUGAR(糖果手機)',
#   'bundle_deal_info': None,
#   'can_use_bundle_deal': False,
#   'can_use_wholesale': False,
#   'catid': 70,
#   'cb_option': 0,
#   'cmt_count': 2,
#   'coin_earn_items': None,
#   'coin_spend_cash_unit': None,
#   'condition': 1,
#   'currency': 'TWD',
#   'description': None,
#   'discount': None,
#   'estimated_days': 7,
#   'flash_sale': None,
#   'free_return_day': 15,
#   'has_lowest_price_guarantee': False,
#   'hashtag_list': [],
#   'image': '60d466134c9b972e9b69c9bd85d96ec1',
#   'image_list': ['60d466134c9b972e9b69c9bd85d96ec1',
#    'e57b7a625044a47a9d3b8f8103bedc46',
#    '0f6e7e38cc64ff4be8044f37f0b8ae12',
#    '3d9992dbe0572a20d3d80f91d6da4d44',
#    'f1937e868063cae4071d21c253047138'],
#   'installment_plans': None,
#   'is_adult': None,
#   'is_category_failed': False,
#   'is_cc_installment_payment_eligible': False,
#   'is_installment_payment_eligible': False,
#   'is_non_cc_installment_payment_eligible': False,
#   'is_official_shop': False,
#   'is_pre_order': True,
#   'is_shopee_verified': False,
#   'item_status': 'normal',
#   'itemid': 690930182,
#   'liked': False,
#   'liked_count': 21,
#   'models': [],
#   'name': '(目前缺貨中）SUGAR C7 5吋 超殺超高CP值手機 容量3+32G 香檳金現貨供應中 頻段4+2 直接下標',
#   'offer_count': 0,
#   'price': 299000000,
#   'price_before_discount': 0,
#   'price_max': -1,
#   'price_max_before_discount': 0,
#   'price_min': -1,
#   'price_min_before_discount': 0,
#   'rating_count': [0, 0, 0, 0, 0, 0],
#   'rating_star': 0,
#   'raw_discount': None,
#   'rcount_with_context': 0,
#   'rcount_with_image': 0,
#   'service_by_shopee_flag': 0,
#   'shopid': 10936709,
#   'show_discount': 0,
#   'show_free_shipping': False,
#   'sold': 4,
#   'stock': 6,
#   'sub_catid': 2609,
#   'third_catid': 5809,
#   'videos': [],
#   'wholesale_tier_list': []},
#  {'attributes': [],
#   'brand': 'SUGAR(糖果手機)',
#   'bundle_deal_info': None,
#   'can_use_bundle_deal': False,
#   'can_use_wholesale': False,
#   'catid': 70,
#   'cb_option': 0,
#   'cmt_count': 14,
#   'coin_earn_items': None,
#   'coin_spend_cash_unit': None,
#   'condition': 1,
#   'currency': 'TWD',
#   'description': None,
#   'discount': '9.3',
#   'estimated_days': 3,
#   'flash_sale': None,
#   'free_return_day': 15,
#   'has_lowest_price_guarantee': False,
#   'hashtag_list': [],
#   'image': 'd68862b7143855fe1269e00f1a330732',
#   'image_list': ['d68862b7143855fe1269e00f1a330732',
#    '61dc614eee0c29c0e8cb7d77d9c2fb34',
#    '90720167a0321aea66b18dd6924b5ca4',
#    '21ad9452c6201d5c38479ad92d7484d0',
#    '9a3ae832458e4ebebd4a08fbdccbf5ac',
#    'e859d7be02efada8888fe1f2f2fa33df',
#    'a8dd3941c1b145056c9e116251cb4b5e',
#    'dd8d8e7c0fd233f2c21b36c24fea785c'],
#   'installment_plans': None,
#   'is_adult': None,
#   'is_category_failed': False,
#   'is_cc_installment_payment_eligible': False,
#   'is_installment_payment_eligible': False,
#   'is_non_cc_installment_payment_eligible': False,
#   'is_official_shop': True,
#   'is_pre_order': False,
#   'is_shopee_verified': True,
#   'item_status': 'normal',
#   'itemid': 668288646,
#   'liked': False,
#   'liked_count': 35,
#   'models': [{'ctime': 1510134246,
#     'currency': 'TWD',
#     'extinfo': {'promo_source': 1,
#      'seller_promotion_limit': 0,
#      'seller_promotion_refresh_time': 1522510202,
#      'stockout_time': 0},
#     'itemid': 668288646,
#     'modelid': 508457098,
#     'mtime': 1520226063,
#     'name': '香檳金',
#     'price': 650000000,
#     'price_before_discount': 699000000,
#     'promotionid': 1003170848,
#     'rebate_price': 0,
#     'sku': '',
#     'sold': 8,
#     'status': 1,
#     'stock': 1},
#    {'ctime': 1510377636,
#     'currency': 'TWD',
#     'extinfo': {'promo_source': 1,
#      'seller_promotion_limit': 0,
#      'seller_promotion_refresh_time': 1522510202,
#      'stockout_time': 1519200090},
#     'itemid': 668288646,
#     'modelid': 518067356,
#     'mtime': 1519831866,
#     'name': '鈦空灰',
#     'price': 650000000,
#     'price_before_discount': 699000000,
#     'promotionid': 1003170848,
#     'rebate_price': 0,
#     'sku': '',
#     'sold': 3,
#     'status': 1,
#     'stock': 0},
#    {'ctime': 1511354380,
#     'currency': 'TWD',
#     'extinfo': {'promo_source': 1,
#      'seller_promotion_limit': 0,
#      'seller_promotion_refresh_time': 1522510202,
#      'stockout_time': 1519200090},
#     'itemid': 668288646,
#     'modelid': 554437861,
#     'mtime': 1519831866,
#     'name': '馬賽紅',
#     'price': 650000000,
#     'price_before_discount': 699000000,
#     'promotionid': 1003170848,
#     'rebate_price': 0,
#     'sku': '',
#     'sold': 0,
#     'status': 1,
#     'stock': 0}],
#   'name': '手機先生【SUGAR】C11 4G+64G 5.7吋 全螢幕手機 4G+3G 雙卡雙待機 送雙肩後背包+保護貼',
#   'offer_count': 0,
#   'price': 650000000,
#   'price_before_discount': 699000000,
#   'price_max': 650000000,
#   'price_max_before_discount': 699000000,
#   'price_min': 650000000,
#   'price_min_before_discount': 699000000,
#   'rating_count': [8, 0, 0, 0, 0, 8],
#   'rating_star': 5.0,
#   'raw_discount': 7,
#   'rcount_with_context': 8,
#   'rcount_with_image': 1,
#   'service_by_shopee_flag': 0,
#   'shopid': 3274118,
#   'show_discount': 7,
#   'show_free_shipping': True,
#   'sold': 4,
#   'stock': 1,
#   'sub_catid': 2609,
#   'third_catid': 5809,
#   'videos': [{'duration': 30,
#     'thumb_url': 'c54e0748be5b964c5141b72cd04bb4ad',
#     'video_id': 'I3ECizYKOVXql3OF'}],
#   'wholesale_tier_list': []},
#  {'attributes': [],
#   'brand': 'SUGAR(糖果手機)',
#   'bundle_deal_info': None,
#   'can_use_bundle_deal': False,
#   'can_use_wholesale': False,
#   'catid': 70,
#   'cb_option': 0,
#   'cmt_count': 1,
#   'coin_earn_items': None,
#   'coin_spend_cash_unit': None,
#   'condition': 1,
#   'currency': 'TWD',
#   'description': None,
#   'discount': None,
#   'estimated_days': 3,
#   'flash_sale': None,
#   'free_return_day': 15,
#   'has_lowest_price_guarantee': False,
#   'hashtag_list': [],
#   'image': 'df82606353e6364ef151d8b9b0b6b57b',
#   'image_list': ['df82606353e6364ef151d8b9b0b6b57b',
#    'e84c61490ccd712cc6b4989301ff3f88'],
#   'installment_plans': None,
#   'is_adult': None,
#   'is_category_failed': False,
#   'is_cc_installment_payment_eligible': False,
#   'is_installment_payment_eligible': False,
#   'is_non_cc_installment_payment_eligible': False,
#   'is_official_shop': False,
#   'is_pre_order': False,
#   'is_shopee_verified': False,
#   'item_status': 'normal',
#   'itemid': 937723143,
#   'liked': False,
#   'liked_count': 13,
#   'models': [{'ctime': 1519370863,
#     'currency': 'TWD',
#     'extinfo': {'stockout_time': 0},
#     'itemid': 937723143,
#     'modelid': 786808464,
#     'mtime': 1519555779,
#     'name': '黑色',
#     'price': 319000000,
#     'price_before_discount': 0,
#     'promotionid': 0,
#     'rebate_price': 0,
#     'sku': '',
#     'sold': 2,
#     'status': 1,
#     'stock': 1},
#    {'ctime': 1519555779,
#     'currency': 'TWD',
#     'extinfo': {'stockout_time': 0},
#     'itemid': 937723143,
#     'modelid': 789997369,
#     'mtime': 1519555779,
#     'name': '金色',
#     'price': 319000000,
#     'price_before_discount': 0,
#     'promotionid': 0,
#     'rebate_price': 0,
#     'sold': 0,
#     'status': 1,
#     'stock': 1}],
#   'name': '糖果 SUGAR Y8 MAX 現貨 全新未拆',
#   'offer_count': 0,
#   'price': 319000000,
#   'price_before_discount': 0,
#   'price_max': 319000000,
#   'price_max_before_discount': -1,
#   'price_min': 319000000,
#   'price_min_before_discount': -1,
#   'rating_count': [1, 0, 0, 0, 0, 1],
# ...
#   'is_cc_installment_payment_eligible': False,
#   'is_installment_payment_eligible': False,
#   'is_non_cc_installment_payment_eligible': False,
#   'is_official_shop': False,
#   'is_pre_order': False,
#   'is_shopee_verified': False,
#   'item_status': 'normal',
#   'itemid': 790338604,
#   'liked': False,
#   'liked_count': 106,
#   'models': [{'ctime': 1514370340,
#     'currency': 'TWD',
#     'extinfo': {'promo_source': 1,
#      'seller_promotion_limit': 0,
#      'seller_promotion_refresh_time': 1522425602,
#      'stockout_time': 0},
#     'itemid': 790338604,
#     'modelid': 670056939,
#     'mtime': 1518276524,
#     'name': 'K8迷你藍芽耳機(黑)',
#     'price': 36800000,
#     'price_before_discount': 45000000,
#     'promotionid': 1002999852,
#     'rebate_price': 0,
#     'sku': 'SA0056BL',
#     'sold': 45,
#     'status': 1,
#     'stock': 73},
#    {'ctime': 1514370340,
#     'currency': 'TWD',
#     'extinfo': {'promo_source': 1,
#      'seller_promotion_limit': 0,
#      'seller_promotion_refresh_time': 1522425602,
#      'stockout_time': 0},
#     'itemid': 790338604,
#     'modelid': 670056940,
#     'mtime': 1518276524,
#     'name': 'K8迷你藍芽耳機(白)',
#     'price': 36800000,
#     'price_before_discount': 45000000,
#     'promotionid': 1002999852,
#     'rebate_price': 0,
#     'sku': 'SA0056W',
#     'sold': 13,
#     'status': 1,
#     'stock': 90}],
#   'name': '原廠無線微型藍牙耳機迷妳超小隱形4.1耳塞式開車音樂迷妳藍芽耳機蘋果iphone7/iphone6安卓三星HTC手機通用',
#   'offer_count': 0,
#   'price': 36800000,
#   'price_before_discount': 45000000,
#   'price_max': 36800000,
#   'price_max_before_discount': 45000000,
#   'price_min': 36800000,
#   'price_min_before_discount': 45000000,
#   'rating_count': [28, 0, 0, 0, 2, 26],
#   'rating_star': 4.928571428571429,
#   'raw_discount': 18,
#   'rcount_with_context': 21,
#   'rcount_with_image': 0,
#   'service_by_shopee_flag': 0,
#   'shopid': 49198003,
#   'show_discount': 18,
#   'show_free_shipping': False,
#   'sold': 33,
#   'stock': 163,
#   'sub_catid': 2684,
#   'third_catid': 7976,
#   'videos': [],
#   'wholesale_tier_list': []},
#  {'attributes': [],
#   'brand': '自有品牌',
#   'bundle_deal_info': None,
#   'can_use_bundle_deal': False,
#   'can_use_wholesale': False,
#   'catid': 70,
#   'cb_option': 0,
#   'cmt_count': 103,
#   'coin_earn_items': None,
#   'coin_spend_cash_unit': None,
#   'condition': 1,
#   'currency': 'TWD',
#   'description': None,
#   'discount': None,
#   'estimated_days': 7,
#   'flash_sale': None,
#   'free_return_day': 15,
#   'has_lowest_price_guarantee': False,
#   'hashtag_list': [],
#   'image': '6b0f45d184f1a5b7857d2dc84d589fd8',
#   'image_list': ['6b0f45d184f1a5b7857d2dc84d589fd8',
#    '9dfab05003c21482919a037fed5ac21a',
#    '64342647f0b04a8c8d1fb6f4e11829e4',
#    'f158fa51240f3e7cf62bca2f49a2f27b',
#    '7776725c3d158e6747d8d7d065e27aff',
#    'e637c5a70d8f970fef9252ee7d86f759',
#    '12683ad514a819ed28d529f684684467',
#    '868a875be4cf1ff96a3080c25bbac87a'],
#   'installment_plans': None,
#   'is_adult': None,
#   'is_category_failed': False,
#   'is_cc_installment_payment_eligible': False,
#   'is_installment_payment_eligible': False,
#   'is_non_cc_installment_payment_eligible': False,
#   'is_official_shop': False,
#   'is_pre_order': True,
#   'is_shopee_verified': True,
#   'item_status': 'normal',
#   'itemid': 891219167,
#   'liked': False,
#   'liked_count': 147,
#   'models': [{'ctime': 1517640334,
#     'currency': 'TWD',
#     'extinfo': {'stockout_time': 0},
#     'itemid': 891219167,
#     'modelid': 768077092,
#     'mtime': 1517640334,
#     'name': 'i8/i7(4.7)：玫瑰金',
#     'price': 29900000,
#     'price_before_discount': 0,
#     'promotionid': 0,
#     'rebate_price': 0,
#     'sold': 10,
#     'status': 1,
#     'stock': 85},
#    {'ctime': 1517640334,
#     'currency': 'TWD',
#     'extinfo': {'stockout_time': 0},
#     'itemid': 891219167,
#     'modelid': 768077093,
#     'mtime': 1517640334,
#     'name': 'i8/i7(4.7)：黑色',
#     'price': 29900000,
#     'price_before_discount': 0,
#     'promotionid': 0,
#     'rebate_price': 0,
#     'sold': 27,
#     'status': 1,
#     'stock': 71},
#    {'ctime': 1517640334,
#     'currency': 'TWD',
#     'extinfo': {'stockout_time': 0},
#     'itemid': 891219167,
#     'modelid': 768077094,
#     'mtime': 1517640334,
#     'name': 'i8/i7(4.7)：金色',
#     'price': 29900000,
#     'price_before_discount': 0,
#     'promotionid': 0,
#     'rebate_price': 0,
#     'sold': 4,
#     'status': 1,
#     'stock': 96},
#    {'ctime': 1517640334,
#     'currency': 'TWD',
#     'extinfo': {'stockout_time': 0},
#     'itemid': 891219167,
#     'modelid': 768077095,
#     'mtime': 1517640334,
#     'name': 'i8/i7(4.7)：白色',
#     'price': 29900000,
#     'price_before_discount': 0,
#     'promotionid': 0,
#     'rebate_price': 0,
#     'sold': 7,
#     'status': 1,
#     'stock': 91},
#    {'ctime': 1517640334,
#     'currency': 'TWD',
#     'extinfo': {'stockout_time': 0},
#     'itemid': 891219167,
#     'modelid': 768077096,
#     'mtime': 1517640334,
#     'name': 'i8+/i7+(5.5)：玫瑰金',
#     'price': 29900000,
#     'price_before_discount': 0,
#     'promotionid': 0,
#     'rebate_price': 0,
#     'sold': 16,
#     'status': 1,
#     'stock': 77},
#    {'ctime': 1517640334,
#     'currency': 'TWD',
#     'extinfo': {'stockout_time': 0},
#     'itemid': 891219167,
#     'modelid': 768077097,
#     'mtime': 1517640334,
#     'name': 'i8+/i7+(5.5)：黑色',
#     'price': 29900000,
#     'price_before_discount': 0,
#     'promotionid': 0,
#     'rebate_price': 0,
#     'sold': 24,
#     'status': 1,
#     'stock': 70},
#    {'ctime': 1517640334,
#     'currency': 'TWD',
#     'extinfo': {'stockout_time': 0},
#     'itemid': 891219167,
#     'modelid': 768077098,
#     'mtime': 1517640334,
#     'name': 'i8+/i7+(5.5)：金色',
#     'price': 29900000,
#     'price_before_discount': 0,
#     'promotionid': 0,
#     'rebate_price': 0,
#     'sold': 4,
#     'status': 1,
#     'stock': 94},
#    {'ctime': 1517640334,
#     'currency': 'TWD',
#     'extinfo': {'stockout_time': 0},
#     'itemid': 891219167,
#     'modelid': 768077099,
#     'mtime': 1517640334,
#     'name': 'i8+/i7+(5.5)：白色',
#     'price': 29900000,
#     'price_before_discount': 0,
#     'promotionid': 0,
#     'rebate_price': 0,
#     'sold': 6,
#     'status': 1,
#     'stock': 93},
#    {'ctime': 1517640334,
#     'currency': 'TWD',
#     'extinfo': {'stockout_time': 0},
#     'itemid': 891219167,
#     'modelid': 768077100,
#     'mtime': 1517640334,
#     'name': 'i6/i6s(4.7)：玫瑰金',
#     'price': 29900000,
#     'price_before_discount': 0,
#     'promotionid': 0,
#     'rebate_price': 0,
#     'sold': 30,
#     'status': 1,
#     'stock': 66},
#    {'ctime': 1517640334,
#     'currency': 'TWD',
#     'extinfo': {'stockout_time': 0},
#     'itemid': 891219167,
#     'modelid': 768077101,
#     'mtime': 1517640334,
#     'name': 'i6/i6s(4.7)：黑色',
#     'price': 29900000,
#     'price_before_discount': 0,
#     'promotionid': 0,
#     'rebate_price': 0,
#     'sold': 22,
#     'status': 1,
#     'stock': 67},
#    {'ctime': 1517640334,
#     'currency': 'TWD',
#     'extinfo': {'stockout_time': 0},
#     'itemid': 891219167,
#     'modelid': 768077102,
#     'mtime': 1521013010,
#     'name': 'i6/i6s(4.7)：金色',
#     'price': 29900000,
#     'price_before_discount': 0,
#     'promotionid': 0,
#     'rebate_price': 0,
#     'sold': 8,
#     'status': 1,
#     'stock': 98},
#    {'ctime': 1517640334,
#     'currency': 'TWD',
#     'extinfo': {'stockout_time': 0},
#     'itemid': 891219167,
#     'modelid': 768077103,
#     'mtime': 1517640334,
#     'name': 'i6/i6s(4.7)：白色',
#     'price': 29900000,
#     'price_before_discount': 0,
#     'promotionid': 0,
#     'rebate_price': 0,
#     'sold': 8,
#     'status': 1,
#     'stock': 90},
#    {'ctime': 1517640334,
#     'currency': 'TWD',
#     'extinfo': {'stockout_time': 0},
#     'itemid': 891219167,
#     'modelid': 768077104,
#     'mtime': 1517640334,
#     'name': 'i6+/i6s+(5.5)：玫瑰金',
#     'price': 29900000,
#     'price_before_discount': 0,
#     'promotionid': 0,
#     'rebate_price': 0,
#     'sold': 25,
#     'status': 1,
#     'stock': 73},
#    {'ctime': 1517640334,
#     'currency': 'TWD',
#     'extinfo': {'stockout_time': 0},
#     'itemid': 891219167,
#     'modelid': 768077105,
#     'mtime': 1517640334,
#     'name': 'i6+/i6s+(5.5)：黑色',
#     'price': 29900000,
#     'price_before_discount': 0,
#     'promotionid': 0,
#     'rebate_price': 0,
#     'sold': 19,
#     'status': 1,
#     'stock': 79},
#    {'ctime': 1517640334,
#     'currency': 'TWD',
#     'extinfo': {'stockout_time': 0},
#     'itemid': 891219167,
#     'modelid': 768077106,
#     'mtime': 1517640334,
#     'name': 'i6+/i6s+(5.5)：金色',
#     'price': 29900000,
#     'price_before_discount': 0,
#     'promotionid': 0,
#     'rebate_price': 0,
#     'sold': 5,
#     'status': 1,
#     'stock': 95},
#    {'ctime': 1517640334,
#     'currency': 'TWD',
#     'extinfo': {'stockout_time': 0},
#     'itemid': 891219167,
#     'modelid': 768077107,
#     'mtime': 1517640334,
#     'name': 'i6+/i6s+(5.5)：白色',
#     'price': 29900000,
#     'price_before_discount': 0,
#     'promotionid': 0,
#     'rebate_price': 0,
#     'sold': 7,
#     'status': 1,
#     'stock': 92},
#    {'ctime': 1517640334,
#     'currency': 'TWD',
#     'extinfo': {'stockout_time': 0},
#     'itemid': 891219167,
#     'modelid': 768077108,
#     'mtime': 1517640334,
#     'name': 'i5 /i5s/SE：玫瑰金',
#     'price': 29900000,
#     'price_before_discount': 0,
#     'promotionid': 0,
#     'rebate_price': 0,
#     'sold': 1,
#     'status': 1,
#     'stock': 99},
#    {'ctime': 1517640334,
#     'currency': 'TWD',
#     'extinfo': {'stockout_time': 0},
#     'itemid': 891219167,
#     'modelid': 768077109,
#     'mtime': 1517640334,
#     'name': 'i5 /i5s/SE：黑色',
#     'price': 29900000,
#     'price_before_discount': 0,
#     'promotionid': 0,
#     'rebate_price': 0,
#     'sold': 2,
#     'status': 1,
#     'stock': 97},
#    {'ctime': 1517640334,
#     'currency': 'TWD',
#     'extinfo': {'stockout_time': 0},
#     'itemid': 891219167,
#     'modelid': 768077110,
#     'mtime': 1517640334,
#     'name': 'i5 /i5s/SE：金色',
#     'price': 29900000,
#     'price_before_discount': 0,
#     'promotionid': 0,
#     'rebate_price': 0,
#     'sold': 0,
#     'status': 1,
#     'stock': 100},
#    {'ctime': 1517640334,
#     'currency': 'TWD',
#     'extinfo': {'stockout_time': 0},
#     'itemid': 891219167,
#     'modelid': 768077111,
#     'mtime': 1517640334,
#     'name': 'i5 /i5s/SE：白色',
#     'price': 29900000,
#     'price_before_discount': 0,
#     'promotionid': 0,
#     'rebate_price': 0,
#     'sold': 1,
#     'status': 1,
#     'stock': 99}],
#   'name': '月賣500個iphone行動電源i8/i8+/i7/i7+/I6/I6＋背夾行動電源手機殼充電手機殼無缐充電蘋果行動電源',
#   'offer_count': 0,
#   'price': 29900000,
#   'price_before_discount': 0,
#   'price_max': 29900000,
#   'price_max_before_discount': -1,
#   'price_min': 29900000,
#   'price_min_before_discount': -1,
#   'rating_count': [100, 0, 1, 1, 10, 88],
#   'rating_star': 4.85,
#   'raw_discount': None,
#   'rcount_with_context': 57,
#   'rcount_with_image': 0,
#   'service_by_shopee_flag': 0,
#   'shopid': 4067127,
#   'show_discount': 0,
#   'show_free_shipping': True,
#   'sold': 247,
#   'stock': 1732,
#   'sub_catid': 1575,
#   'third_catid': 9366,
#   'videos': [],
#   'wholesale_tier_list': []},
#  {'attributes': [],
#   'brand': '',
#   'bundle_deal_info': None,
#   'can_use_bundle_deal': False,
#   'can_use_wholesale': True,
#   'catid': 70,
#   'cb_option': 0,
#   'cmt_count': 81,
#   'coin_earn_items': None,
#   'coin_spend_cash_unit': None,
#   'condition': 1,
#   'currency': 'TWD',
#   'description': None,
#   'discount': None,
#   'estimated_days': 3,
#   'flash_sale': None,
#   'free_return_day': 15,
#   'has_lowest_price_guarantee': False,
#   'hashtag_list': [],
#   'image': '53a3c7bbaf10614dd7f5484b22154028',
#   'image_list': ['53a3c7bbaf10614dd7f5484b22154028',
#    '20e844db7097b833ef8b6120855ea479',
#    '05377ab493c85032cff65dfc8d31937d',
#    '8ee3c20de0894b1246220bcb235be88c',
#    'b0ae797ecd1c4eef07cfe8150ce50f41',
#    '22e1e117d6a424a9bd728c97e28cce23',
#    '9fe1ba767a8fc25fd9bcb9a9ba8e91c0',
#    '0bc7e5728ce9a585f6adfff3a65f9944',
#    'c065dcc755af1ebe57149a628a8c663e'],
#   'installment_plans': None,
#   'is_adult': None,
#   'is_category_failed': False,
#   'is_cc_installment_payment_eligible': False,
#   'is_installment_payment_eligible': False,
#   'is_non_cc_installment_payment_eligible': False,
#   'is_official_shop': True,
#   'is_pre_order': False,
#   'is_shopee_verified': True,
#   'item_status': 'normal',
#   'itemid': 48211966,
#   'liked': False,
#   'liked_count': 77,
#   'models': [{'ctime': 1470034424,
#     'currency': 'TWD',
#     'extinfo': {'has_shopee_promo': False,
#      'seller_promotion_limit': 0,
#      'seller_promotion_refresh_time': 0},
#     'itemid': 48211966,
#     'modelid': 29864288,
#     'mtime': 1499305153,
#     'name': '單車黑色',
#     'price': 12800000,
#     'price_before_discount': 0,
#     'promotionid': 0,
#     'rebate_price': 0,
#     'sku': '',
#     'sold': 73,
#     'status': 1,
#     'stock': 75},
#    {'ctime': 1470034424,
#     'currency': 'TWD',
#     'extinfo': {'has_shopee_promo': False,
#      'seller_promotion_limit': 0,
#      'seller_promotion_refresh_time': 0},
#     'itemid': 48211966,
#     'modelid': 29864289,
#     'mtime': 1499305153,
#     'name': '單車黑紅色',
#     'price': 12800000,
#     'price_before_discount': 0,
#     'promotionid': 0,
#     'rebate_price': 0,
#     'sku': '',
#     'sold': 26,
#     'status': 1,
#     'stock': 99},
#    {'ctime': 1471931652,
#     'currency': 'TWD',
#     'extinfo': {'has_shopee_promo': False,
#      'seller_promotion_limit': 0,
#      'seller_promotion_refresh_time': 0},
#     'itemid': 48211966,
#     'modelid': 43587868,
#     'mtime': 1499305153,
#     'name': '機車黑色',
#     'price': 12800000,
#     'price_before_discount': 0,
#     'promotionid': 0,
#     'rebate_price': 0,
#     'sku': '',
#     'sold': 36,
#     'status': 1,
#     'stock': 81},
#    {'ctime': 1471931652,
#     'currency': 'TWD',
#     'extinfo': {'has_shopee_promo': False,
#      'seller_promotion_limit': 0,
#      'seller_promotion_refresh_time': 0},
#     'itemid': 48211966,
#     'modelid': 43587869,
#     'mtime': 1499305153,
#     'name': '機車黑紅色',
#     'price': 12800000,
#     'price_before_discount': 0,
#     'promotionid': 0,
#     'rebate_price': 0,
#     'sku': '',
#     'sold': 14,
#     'status': 1,
#     'stock': 93}],
#   'name': '機車 自行車 摩托車 單車 手機架 GPS導航架 支架 多用途支架 手機支架Pokemon GO',
#   'offer_count': 0,
#   'price': 12800000,
#   'price_before_discount': 0,
#   'price_max': 12800000,
#   'price_max_before_discount': -1,
#   'price_min': 12800000,
#   'price_min_before_discount': -1,
#   'rating_count': [76, 1, 0, 2, 4, 69],
#   'rating_star': 4.842105263157895,
#   'raw_discount': None,
#   'rcount_with_context': 23,
#   'rcount_with_image': 0,
#   'service_by_shopee_flag': 0,
#   'shopid': 1494597,
#   'show_discount': 0,
#   'show_free_shipping': True,
#   'sold': 13,
#   'stock': 348,
#   'sub_catid': 7981,
#   'third_catid': 7982,
#   'videos': [],
#   'wholesale_tier_list': [{'min_count': 2, 'price': 11800000}]},
#  {'attributes': [],
#   'brand': None,
#   'bundle_deal_info': None,
#   'can_use_bundle_deal': False,
#   'can_use_wholesale': False,
#   'catid': 10076,
#   'cb_option': 0,
#   'cmt_count': 156,
#   'coin_earn_items': None,
#   'coin_spend_cash_unit': None,
#   'condition': 1,
#   'currency': 'TWD',
#   'description': None,
#   'discount': None,
#   'estimated_days': 3,
#   'flash_sale': None,
#   'free_return_day': 15,
#   'has_lowest_price_guarantee': False,
#   'hashtag_list': [],
#   'image': '0c31b32feacbbd34939662a7810faa74',
#   'image_list': ['0c31b32feacbbd34939662a7810faa74',
#    '46c8c0a64e32151a0d0241df38b29adc',
#    '32b322c2f7e15bb501df50c418be8a4b'],
#   'installment_plans': None,
#   'is_adult': None,
#   'is_category_failed': False,
#   'is_cc_installment_payment_eligible': False,
#   'is_installment_payment_eligible': False,
#   'is_non_cc_installment_payment_eligible': False,
#   'is_official_shop': False,
#   'is_pre_order': False,
#   'is_shopee_verified': False,
#   'item_status': 'normal',
#   'itemid': 242609117,
#   'liked': False,
#   'liked_count': 72,
#   'models': [],
#   'name': '<黏貼小舖>買十送一 磁鐵支架 磁性 支架 手機 平板 懶人夾 出風口 玻璃支架 行車記錄器 導航 磁鐵 手機架',
#   'offer_count': 0,
#   'price': 3600000,
#   'price_before_discount': 0,
#   'price_max': -1,
#   'price_max_before_discount': 0,
#   'price_min': -1,
#   'price_min_before_discount': 0,
#   'rating_count': [153, 0, 1, 7, 7, 138],
#   'rating_star': 4.8431372549019605,
#   'raw_discount': None,
#   'rcount_with_context': 75,
#   'rcount_with_image': 0,
#   'service_by_shopee_flag': 0,
#   'shopid': 2841469,
#   'show_discount': 0,
#   'show_free_shipping': False,
#   'sold': 46,
#   'stock': 531,
#   'sub_catid': 10078,
#   'third_catid': 10126,
#   'videos': [],
#   'wholesale_tier_list': []}]
